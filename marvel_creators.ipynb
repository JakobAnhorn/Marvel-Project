# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import requests
import json
from config import omdb_api_key

# %%
#create url for marvel movies
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + omdb_api_key

# %%
#create request variable
response = requests.get(url + "Iron Man" + api_key).json()
response
# Out:
# {'Title': 'Iron Man',
#  'Year': '2008',
#  'Rated': 'PG-13',
#  'Released': '02 May 2008',
#  'Runtime': '126 min',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Director': 'Jon Favreau',
#  'Writer': 'Mark Fergus, Hawk Ostby, Art Marcum',
#  'Actors': 'Robert Downey Jr., Gwyneth Paltrow, Terrence Howard',
#  'Plot': 'After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.',
#  'Language': 'English, Persian, Urdu, Arabic, Kurdish, Hindi, Hungarian',
#  'Country': 'United States, Canada',
#  'Awards': 'Nominated for 2 Oscars. 22 wins & 73 nominations total',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMTczNTI2ODUwOF5BMl5BanBnXkFtZTcwMTU0NTIzMw@@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.9/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '94%'},
#   {'Source': 'Metacritic', 'Value': '79/100'}],
#  'Metascore': '79',
#  'imdbRating': '7.9',
# ...

# %%
marv_url = ((url + "Iron Man" + api_key))
print(marv_url)
# Out:
# http://www.omdbapi.com/?t=Iron Man&apikey=b8debd85

# %%
#testing the api request loop
brap=[]
trap=[]

list = ["Ant-Man", "Marvel", "Iron Man"]

for i in list:
    data = requests.get(url + i + api_key).json()
    author = data["Writer"]
    sales = data["BoxOffice"]
    brap.append(author)
    trap.append(sales)
print(brap)
print(trap)
# Out:
# ['Edgar Wright, Joe Cornish, Adam McKay', 'Anna Boden, Ryan Fleck, Geneva Robertson-Dworet', 'Mark Fergus, Hawk Ostby, Art Marcum']
# ['$180,202,163', '$426,829,839', '$319,034,126']

# %%
#open mcu csv file
mcu_df = pd.read_csv("./resources/mcu.csv")
mcu_df
# Out:
#        Unnamed: 0       character  \
# 0               0      TONY STARK
# 1               1  IRON MAN JIMMY
# 2               2      TONY STARK
# 3               3         RAMIREZ
# 4               4      TONY STARK
# ...           ...             ...
# 15719       15719    STEVE ROGERS
# 15720       15720      SAM WILSON
# 15721       15721    STEVE ROGERS
# 15722       15722      SAM WILSON
# 15723       15723    STEVE ROGERS
#
#                                                     line              movie  \
# 0      Oh, I get it.  You guys aren’t allowed to talk...           Iron Man
# 1                            No.  We’re allowed to talk.           Iron Man
# 2                         Oh.  I see.  So it’s personal.           Iron Man
# 3                           I think they’re intimidated.           Iron Man
# 4      Good God, you’re a woman. I, honestly, I could...           Iron Man
# ...                                                  ...                ...
# ...

# %%
#determine data type of columns
mcu_df.dtypes
# Out:
# Unnamed: 0                  int64
# character                  object
# line                       object
# movie                      object
# year                        int64
# words                       int64
# Adam McKay                   bool
# Anna Boden                   bool
# Art Marcum                   bool
# Ashley Edward Miller         bool
# Chris McKenna                bool
# Christopher Ford             bool
# Christopher Markus           bool
# Christopher Yost             bool
# Craig Kyle                   bool
# Don Payne                    bool
# Drew Pearce                  bool
# Edgar Wright                 bool
# Eric Pearson                 bool
# Erik Sommers                 bool
# Geneva Robertson-Dworet      bool
# Hawk Ostby                   bool
# James Gunn                   bool
# Joe Cornish                  bool
# Joe Robert Cole              bool
# John Francis Daley           bool
# Jon Watts                    bool
# ...

# %%
mcu_df.head(50)
# Out:
#     Unnamed: 0           character  \
# 0            0          TONY STARK
# 1            1      IRON MAN JIMMY
# 2            2          TONY STARK
# 3            3             RAMIREZ
# 4            4          TONY STARK
# 5            5      IRON MAN JIMMY
# 6            6          TONY STARK
# 7            7      IRON MAN JIMMY
# 8            8          TONY STARK
# 9            9               PRATT
# 10          10          TONY STARK
# 11          11               PRATT
# 12          12          TONY STARK
# 13          13               PRATT
# 14          14        JAMES RHODES
# 15          15            NARRATOR
# 16          16        JAMES RHODES
# 17          17       OBADIAH STANE
# 18          18          TONY STARK
# 19          19               WOMAN
# 20          20          TONY STARK
# 21          21        JAMES RHODES
# 22          22          TONY STARK
# 23          23        JAMES RHODES
# 24          24          TONY STARK
# ...

# %%
#change movie column name
alt_mcu_df = mcu_df.rename(columns={"movie": "movie_title"})
alt_mcu_df
# Out:
#        Unnamed: 0       character  \
# 0               0      TONY STARK
# 1               1  IRON MAN JIMMY
# 2               2      TONY STARK
# 3               3         RAMIREZ
# 4               4      TONY STARK
# ...           ...             ...
# 15719       15719    STEVE ROGERS
# 15720       15720      SAM WILSON
# 15721       15721    STEVE ROGERS
# 15722       15722      SAM WILSON
# 15723       15723    STEVE ROGERS
#
#                                                     line        movie_title  \
# 0      Oh, I get it.  You guys aren’t allowed to talk...           Iron Man
# 1                            No.  We’re allowed to talk.           Iron Man
# 2                         Oh.  I see.  So it’s personal.           Iron Man
# 3                           I think they’re intimidated.           Iron Man
# 4      Good God, you’re a woman. I, honestly, I could...           Iron Man
# ...                                                  ...                ...
# ...

# %%
# alt_mcu_df.set_index(['movie_title'], inplace=True)
# alt_mcu_df

# %%
# ultra_df = alt_mcu_df.groupby("movie_title").sum()
# ultra_df

# %%
# ultra_df.columns

# %%
# ultra_reduced_df = ultra_df[['Adam McKay', 'Anna Boden', 'Art Marcum',
#        'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
#        'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
#        'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz']]
# ultra_reduced_df

# %%
# for index, row in ultra_reduced_df.iterrows():
#     print(row)

# %%
#grouping dataframe by movie_title
grouped_mcu_df = alt_mcu_df.groupby("movie_title").sum()
grouped_mcu_df
# Out:
# C:\Users\wadem\AppData\Local\Temp\ipykernel_6120\137069653.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_mcu_df = alt_mcu_df.groupby("movie_title").sum()
#                                      Unnamed: 0     year  words  Adam McKay  \
# movie_title
# Ant-Man                                 6645942  1668420   9335         828
# Avengers: Age of Ultron                 6847200  1934400  10405           0
# Avengers: Endgame                      16515296  2196672  11677           0
# Avengers: Infinity War                 12645513  1894902   9017           0
# Black Panther                           8779447  1400492   7720           0
# Captain America: Civil War              8282115  1874880  10589           0
# ...

# %%
#Confirming all columns in datafram
grouped_mcu_df.columns
# Out:
# Index(['Unnamed: 0', 'year', 'words', 'Adam McKay', 'Anna Boden', 'Art Marcum',
#        'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
#        'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
#        'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz'],
#       dtype='object')

# %%
#eliminating unwanted columns
reduced_mcu_df = grouped_mcu_df[['Adam McKay', 'Anna Boden', 'Art Marcum',
       'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
       'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
       'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
       'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
       'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
       'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
       'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
       'Shane Black', 'Stephen McFeely', 'Zack Stentz']]

reduced_mcu_df
# Out:
#                                      Adam McKay  Anna Boden  Art Marcum  \
# movie_title
# Ant-Man                                     828           0           0
# Avengers: Age of Ultron                       0           0           0
# Avengers: Endgame                             0           0           0
# Avengers: Infinity War                        0           0           0
# Black Panther                                 0           0           0
# Captain America: Civil War                    0           0           0
# Captain America: The First Avenger            0           0           0
# Captain America: The Winter Soldier           0           0           0
# Captain Marvel                                0         699           0
# Guardians of the Galaxy Vol. 2                0           0           0
# Iron Man                                      0           0         687
# Iron Man 2                                    0           0           0
# ...

# %%
# director = []
# for movie in reduced_mcu_df["movie_title"]
# for column in reduced_mcu_df.columns:
#     #dir = reduced_mcu_df.groupby("movie_title")[column].max()
#     diro = reduced_mcu_df[column].max()
#     print(column, diro)
# #     director.append(dir)
# # print(director)

# %%
# for index, row in reduced_mcu_df.iterrows():
#     print(index, row)

# %%
#confirmed reduced columns
reduced_column = reduced_mcu_df.columns
reduced_column
# Out:
# Index(['Adam McKay', 'Anna Boden', 'Art Marcum', 'Ashley Edward Miller',
#        'Chris McKenna', 'Christopher Ford', 'Christopher Markus',
#        'Christopher Yost', 'Craig Kyle', 'Don Payne', 'Drew Pearce',
#        'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz'],
#       dtype='object')

# %%
maker = []
column = reduced_mcu_df.columns
for i in column:
    maker.append(i)
print(maker)
# Out:
# ['Adam McKay', 'Anna Boden', 'Art Marcum', 'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford', 'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne', 'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers', 'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish', 'Joe Robert Cole', 'John Francis Daley', 'Jon Watts', 'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus', 'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck', 'Shane Black', 'Stephen McFeely', 'Zack Stentz']

# %%
#To expand the compressed columns. strictly for visuals
reduced_2_df = reduced_mcu_df[['Adam McKay', 'Anna Boden', 'Art Marcum',
       'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
       'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
       'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
       'Geneva Robertson-Dworet', 'Hawk Ostby']]
reduced_2_df
# Out:
#                                      Adam McKay  Anna Boden  Art Marcum  \
# movie_title
# Ant-Man                                     828           0           0
# Avengers: Age of Ultron                       0           0           0
# Avengers: Endgame                             0           0           0
# Avengers: Infinity War                        0           0           0
# Black Panther                                 0           0           0
# Captain America: Civil War                    0           0           0
# Captain America: The First Avenger            0           0           0
# Captain America: The Winter Soldier           0           0           0
# Captain Marvel                                0         699           0
# Guardians of the Galaxy Vol. 2                0           0           0
# Iron Man                                      0           0         687
# Iron Man 2                                    0           0           0
# ...

# %%
#To expand the compressed columns. Stictly for visuals
reduced_3_df = reduced_mcu_df[['James Gunn', 'Joe Cornish',
       'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
       'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
       'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
       'Shane Black', 'Stephen McFeely', 'Zack Stentz']]
reduced_3_df
# Out:
#                                      James Gunn  Joe Cornish  Joe Robert Cole  \
# movie_title
# Ant-Man                                       0          828                0
# Avengers: Age of Ultron                       0            0                0
# Avengers: Endgame                             0            0                0
# Avengers: Infinity War                        0            0                0
# Black Panther                                 0            0              694
# Captain America: Civil War                    0            0                0
# Captain America: The First Avenger            0            0                0
# Captain America: The Winter Soldier           0            0                0
# Captain Marvel                                0            0                0
# Guardians of the Galaxy Vol. 2              815            0                0
# Iron Man                                      0            0                0
# ...

# %%
#open box-ffice csv file
box_0ffice_df = pd.read_csv("./resources/mcu_box_office.csv")
box_0ffice_df
# Out:
#                                   movie_title  mcu_phase release_date  \
# 0                                    Iron Man          1     5/2/2008
# 1                         The Incredible Hulk          1    6/13/2008
# 2                                  Iron Man 2          1     5/7/2010
# 3                                        Thor          1     5/6/2011
# 4          Captain America: The First Avenger          1    7/22/2011
# 5                                The Avengers          1     5/4/2012
# 6                                  Iron Man 3          2     5/3/2013
# 7                        Thor: The Dark World          2    11/8/2013
# 8         Captain America: The Winter Soldier          2     4/4/2014
# 9                     Guardians of the Galaxy          2     8/1/2014
# 10                    Avengers: Age of Ultron          2     5/1/2015
# 11                                    Ant-Man          2    7/17/2015
# ...

# %%
#merge edited mcu and boxoffice files
merge_df = pd.merge(reduced_mcu_df, box_0ffice_df, on="movie_title")
merge_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %%
#testing
merge_df["movie_title"][0]
# Out:
# 'Ant-Man'

# %%
index = len(merge_df["movie_title"])
index
# Out:
# 17

# %%
# checker = merge_df.iloc[0,1]
# checker

# %%
# if checker > 0:
#     cinema = film
#     author = maker[brap]

# %%
# for brap in range(0, index):
#     checker = merge_df.iloc[brap,brap+1]
#     if checker > 0:
#         film = movies[brap]
#         author = maker[brap]
#         film = movies[brap]
#         print(film, author)
#         #print(author)
#     else:
        
#         continue

# %%
# for index, row in merge_df.iterrows():
#     for column in merge_df.columns:
#         test = merge_df[column].count()
# print(test)
# Out:
# 17

# %%
#confirm merged dataframe columns
merge_df.columns
# Out:
# Index(['movie_title', 'Adam McKay', 'Anna Boden', 'Art Marcum',
#        'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
#        'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
#        'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz', 'mcu_phase',
#        'release_date', 'tomato_meter', 'audience_score', 'movie_duration',
#        'production_budget', 'opening_weekend', 'domestic_box_office',
#        'worldwide_box_office'],
#       dtype='object')

# %%
#group merged dataframe by movie_title
sorted_df = merge_df.sort_values("movie_title")
sorted_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %%
#data types for merged dataframe
sorted_df.dtypes
# Out:
# movie_title                object
# Adam McKay                  int64
# Anna Boden                  int64
# Art Marcum                  int64
# Ashley Edward Miller        int64
# Chris McKenna               int64
# Christopher Ford            int64
# Christopher Markus          int64
# Christopher Yost            int64
# Craig Kyle                  int64
# Don Payne                   int64
# Drew Pearce                 int64
# Edgar Wright                int64
# Eric Pearson                int64
# Erik Sommers                int64
# Geneva Robertson-Dworet     int64
# Hawk Ostby                  int64
# James Gunn                  int64
# Joe Cornish                 int64
# Joe Robert Cole             int64
# John Francis Daley          int64
# Jon Watts                   int64
# Jonathan Goldstein          int64
# Joss Whedon                 int64
# Justin Theroux              int64
# Mark Fergus                 int64
# Matt Holloway               int64
# ...

# %%
#remove comma frm prodiction budget column in order to convert to int for further execution
sorted_df['production_budget'] = sorted_df['production_budget'].replace({'130,000,000':'130000000', '365,000,000': '365000000', '300,000,000': '300000000', '200,000,000': '200000000', '250,000,000':'250000000', '140,000,000':'140000000', '170,000,000':'170000000', '175,000,000':'175000000', '200,000,000':'200000000', '186,000,000':'186000000', '170,000,000':'170000000', '200,000,000':'200000000', '175,000,000':'175000000', '225,000,000':'225000000', '150,000,000':'150000000', '180,000,000':'180000000', '150,000,000':'150000000'})
sorted_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %%
sorted_df.dtypes
# Out:
# movie_title                object
# Adam McKay                  int64
# Anna Boden                  int64
# Art Marcum                  int64
# Ashley Edward Miller        int64
# Chris McKenna               int64
# Christopher Ford            int64
# Christopher Markus          int64
# Christopher Yost            int64
# Craig Kyle                  int64
# Don Payne                   int64
# Drew Pearce                 int64
# Edgar Wright                int64
# Eric Pearson                int64
# Erik Sommers                int64
# Geneva Robertson-Dworet     int64
# Hawk Ostby                  int64
# James Gunn                  int64
# Joe Cornish                 int64
# Joe Robert Cole             int64
# John Francis Daley          int64
# Jon Watts                   int64
# Jonathan Goldstein          int64
# Joss Whedon                 int64
# Justin Theroux              int64
# Mark Fergus                 int64
# Matt Holloway               int64
# ...

# %%
#remove comma frm world wide box office column in order to convert to int for further execution
sorted_df['worldwide_box_office'] = sorted_df['worldwide_box_office'].replace({'518,858,449':'518858449', '1,395,316,979':'1395316979', '2,048,359,754':'2048359754', '1,336,494,321':'1336494321', '1,151,918,521':'1151918521', '370,569,776':'370569776', '714,401,889':'714401889', '1,129,727,388':'1129727388', '869,113,101':'869113101', '585,171,547':'585171547', '621,156,389':'621156389', '1,215,392,272':'1215392272', '878,346,440':'878346440', '1,515,100,211':'1515100211', '449,326,618':'449326618', '850,482,778':'850482778', '644,602,516':'644602516'})
sorted_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %%
#convert colum data to integer
sorted_df['worldwide_box_office'] = sorted_df['worldwide_box_office'].astype(int)
sorted_df.dtypes
# Out:
# movie_title                object
# Adam McKay                  int64
# Anna Boden                  int64
# Art Marcum                  int64
# Ashley Edward Miller        int64
# Chris McKenna               int64
# Christopher Ford            int64
# Christopher Markus          int64
# Christopher Yost            int64
# Craig Kyle                  int64
# Don Payne                   int64
# Drew Pearce                 int64
# Edgar Wright                int64
# Eric Pearson                int64
# Erik Sommers                int64
# Geneva Robertson-Dworet     int64
# Hawk Ostby                  int64
# James Gunn                  int64
# Joe Cornish                 int64
# Joe Robert Cole             int64
# John Francis Daley          int64
# Jon Watts                   int64
# Jonathan Goldstein          int64
# Joss Whedon                 int64
# Justin Theroux              int64
# Mark Fergus                 int64
# Matt Holloway               int64
# ...

# %%
#convert colum data to integer
sorted_df['production_budget'] = sorted_df['production_budget'].astype(int)
sorted_df.dtypes
# Out:
# movie_title                object
# Adam McKay                  int64
# Anna Boden                  int64
# Art Marcum                  int64
# Ashley Edward Miller        int64
# Chris McKenna               int64
# Christopher Ford            int64
# Christopher Markus          int64
# Christopher Yost            int64
# Craig Kyle                  int64
# Don Payne                   int64
# Drew Pearce                 int64
# Edgar Wright                int64
# Eric Pearson                int64
# Erik Sommers                int64
# Geneva Robertson-Dworet     int64
# Hawk Ostby                  int64
# James Gunn                  int64
# Joe Cornish                 int64
# Joe Robert Cole             int64
# John Francis Daley          int64
# Jon Watts                   int64
# Jonathan Goldstein          int64
# Joss Whedon                 int64
# Justin Theroux              int64
# Mark Fergus                 int64
# Matt Holloway               int64
# ...

# %%
#convert datafram column data to datetime
sorted_df['release_date']= pd.to_datetime(sorted_df['release_date'])
sorted_df.dtypes
# Out:
# movie_title                        object
# Adam McKay                          int64
# Anna Boden                          int64
# Art Marcum                          int64
# Ashley Edward Miller                int64
# Chris McKenna                       int64
# Christopher Ford                    int64
# Christopher Markus                  int64
# Christopher Yost                    int64
# Craig Kyle                          int64
# Don Payne                           int64
# Drew Pearce                         int64
# Edgar Wright                        int64
# Eric Pearson                        int64
# Erik Sommers                        int64
# Geneva Robertson-Dworet             int64
# Hawk Ostby                          int64
# James Gunn                          int64
# Joe Cornish                         int64
# Joe Robert Cole                     int64
# John Francis Daley                  int64
# Jon Watts                           int64
# ...

# %%
sorted_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %% [raw]
# sorted_df.columns

# %%
sorted_df.columns
# Out:
# Index(['movie_title', 'Adam McKay', 'Anna Boden', 'Art Marcum',
#        'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
#        'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
#        'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz', 'mcu_phase',
#        'release_date', 'tomato_meter', 'audience_score', 'movie_duration',
#        'production_budget', 'opening_weekend', 'domestic_box_office',
#        'worldwide_box_office'],
#       dtype='object')

# %%
#using api reuqest and for loops to pull movie authors, sales and writers
writer=[]
sales=[]
title=[]
list = sorted_df["movie_title"]

for i in list:
    data = requests.get(url + i + api_key).json()
    author = data["Writer"]
    box_office = data["BoxOffice"]
    tag = data["Title"]
    writer.append(author)
    sales.append(box_office)
    title.append(tag)
print(writer)
print(sales)
print(title)
# Out:
# ['Edgar Wright, Joe Cornish, Adam McKay', 'Joss Whedon, Stan Lee, Jack Kirby', 'Christopher Markus, Stephen McFeely, Stan Lee', 'Ryan Coogler, Joe Robert Cole, Stan Lee', 'Christopher Markus, Stephen McFeely, Joe Simon', 'Christopher Markus, Stephen McFeely, Joe Simon', 'Christopher Markus, Stephen McFeely, Joe Simon', 'Anna Boden, Ryan Fleck, Geneva Robertson-Dworet', 'James Gunn, Dan Abnett, Andy Lanning', 'Mark Fergus, Hawk Ostby, Art Marcum', 'Justin Theroux, Stan Lee, Don Heck', 'Drew Pearce, Shane Black, Stan Lee', 'Jonathan Goldstein, John Francis Daley, Jon Watts', 'Joss Whedon, Zak Penn', 'Ashley Miller, Zack Stentz, Don Payne', 'Eric Pearson, Craig Kyle, Christopher L. Yost', 'Christopher L. Yost, Christopher Markus, Stephen McFeely']
# ...

# %%
#create variable for new dataframe
movie_title = sorted_df["movie_title"]
score = (sorted_df["tomato_meter"] + sorted_df["audience_score"])/2
movie_length = sorted_df["movie_duration"]
money_1 = (sorted_df["worldwide_box_office"])
money_2 = sorted_df["worldwide_box_office"]-sorted_df["production_budget"]
money_3 = money_1/money_2
finance = round((money_3 * 100), 0)
sales = sorted_df["worldwide_box_office"]
production_cost = sorted_df["production_budget"]
release_date = sorted_df["release_date"]

# %%
#new dataframe
mcu_summary = pd.DataFrame({"MCU Movie": movie_title, "Writer": writer, "Release Date": release_date, "Rating": score, "Film Duration (mins)": movie_length, "Production Budget $":production_cost, "Box Office $": sales, "% Profit": finance})
mcu_summary
# Out:
#                               MCU Movie  \
# 0                               Ant-Man
# 1               Avengers: Age of Ultron
# 2                Avengers: Infinity War
# 3                         Black Panther
# 4            Captain America: Civil War
# 5    Captain America: The First Avenger
# 6   Captain America: The Winter Soldier
# 7                        Captain Marvel
# 8        Guardians of the Galaxy Vol. 2
# 9                              Iron Man
# 10                           Iron Man 2
# 11                           Iron Man 3
# 12               Spider-Man: Homecoming
# 13                         The Avengers
# 14                                 Thor
# 15                       Thor: Ragnarok
# 16                 Thor: The Dark World
#
#                                                Writer Release Date  Rating  \
# 0               Edgar Wright, Joe Cornish, Adam McKay   2015-07-17    84.0
# 1                   Joss Whedon, Stan Lee, Jack Kirby   2015-05-01    79.5
# ...

# %%
number = len(mcu_summary["MCU Movie"])
number
# Out:
# 17

# %%
# count = 0
# total = 0
# for writer in adjusted_df.columns:
#     print(writer)
#     #for i in range(0, number):
#     if  writer in mcu_summary["creator"]:
#         count = count + 1
#             #total = total + sales[i]
#         #print(writer, count)
# print(writer)
# print(count)
# print(total)

# %%
mcu_summary["Writer"]
# Out:
# 0                 Edgar Wright, Joe Cornish, Adam McKay
# 1                     Joss Whedon, Stan Lee, Jack Kirby
# 2         Christopher Markus, Stephen McFeely, Stan Lee
# 3               Ryan Coogler, Joe Robert Cole, Stan Lee
# 4        Christopher Markus, Stephen McFeely, Joe Simon
# 5        Christopher Markus, Stephen McFeely, Joe Simon
# 6        Christopher Markus, Stephen McFeely, Joe Simon
# 7       Anna Boden, Ryan Fleck, Geneva Robertson-Dworet
# 8                  James Gunn, Dan Abnett, Andy Lanning
# 9                   Mark Fergus, Hawk Ostby, Art Marcum
# 10                   Justin Theroux, Stan Lee, Don Heck
# 11                   Drew Pearce, Shane Black, Stan Lee
# 12    Jonathan Goldstein, John Francis Daley, Jon Watts
# 13                                Joss Whedon, Zak Penn
# 14                Ashley Miller, Zack Stentz, Don Payne
# 15        Eric Pearson, Craig Kyle, Christopher L. Yost
# 16    Christopher L. Yost, Christopher Markus, Steph...
# ...

# %%
len(mcu_summary["MCU Movie"])
# Out:
# 17

# %%
sorted_df
# Out:
#                             movie_title  Adam McKay  Anna Boden  Art Marcum  \
# 0                               Ant-Man         828           0           0
# 1               Avengers: Age of Ultron           0           0           0
# 2                Avengers: Infinity War           0           0           0
# 3                         Black Panther           0           0           0
# 4            Captain America: Civil War           0           0           0
# 5    Captain America: The First Avenger           0           0           0
# 6   Captain America: The Winter Soldier           0           0           0
# 7                        Captain Marvel           0         699           0
# 8        Guardians of the Galaxy Vol. 2           0           0           0
# 9                              Iron Man           0           0         687
# 10                           Iron Man 2           0           0           0
# ...

# %%
sorted_df.columns
# Out:
# Index(['movie_title', 'Adam McKay', 'Anna Boden', 'Art Marcum',
#        'Ashley Edward Miller', 'Chris McKenna', 'Christopher Ford',
#        'Christopher Markus', 'Christopher Yost', 'Craig Kyle', 'Don Payne',
#        'Drew Pearce', 'Edgar Wright', 'Eric Pearson', 'Erik Sommers',
#        'Geneva Robertson-Dworet', 'Hawk Ostby', 'James Gunn', 'Joe Cornish',
#        'Joe Robert Cole', 'John Francis Daley', 'Jon Watts',
#        'Jonathan Goldstein', 'Joss Whedon', 'Justin Theroux', 'Mark Fergus',
#        'Matt Holloway', 'Paul Rudd', 'Ryan Coogler', 'Ryan Fleck',
#        'Shane Black', 'Stephen McFeely', 'Zack Stentz', 'mcu_phase',
#        'release_date', 'tomato_meter', 'audience_score', 'movie_duration',
#        'production_budget', 'opening_weekend', 'domestic_box_office',
#        'worldwide_box_office'],
#       dtype='object')

# %%
# for index, row in sorted_df.iterrows():
#     print(index, row)

# %%
#sort dataframe via release date
marvel_summary = mcu_summary.sort_values("Release Date")
marvel_summary
# Out:
#                               MCU Movie  \
# 9                              Iron Man
# 10                           Iron Man 2
# 14                                 Thor
# 5    Captain America: The First Avenger
# 13                         The Avengers
# 11                           Iron Man 3
# 16                 Thor: The Dark World
# 6   Captain America: The Winter Soldier
# 1               Avengers: Age of Ultron
# 0                               Ant-Man
# 4            Captain America: Civil War
# 8        Guardians of the Galaxy Vol. 2
# 12               Spider-Man: Homecoming
# 15                       Thor: Ragnarok
# 3                         Black Panther
# 2                Avengers: Infinity War
# 7                        Captain Marvel
#
#                                                Writer Release Date  Rating  \
# 9                 Mark Fergus, Hawk Ostby, Art Marcum   2008-05-02    92.5
# 10                 Justin Theroux, Stan Lee, Don Heck   2010-05-07    71.5
# ...

# %%
#reset dataframe index
marvel_summary = marvel_summary.reset_index()

marvel_summary
# Out:
#     index                            MCU Movie  \
# 0       9                             Iron Man
# 1      10                           Iron Man 2
# 2      14                                 Thor
# 3       5   Captain America: The First Avenger
# 4      13                         The Avengers
# 5      11                           Iron Man 3
# 6      16                 Thor: The Dark World
# 7       6  Captain America: The Winter Soldier
# 8       1              Avengers: Age of Ultron
# 9       0                              Ant-Man
# 10      4           Captain America: Civil War
# 11      8       Guardians of the Galaxy Vol. 2
# 12     12               Spider-Man: Homecoming
# 13     15                       Thor: Ragnarok
# 14      3                        Black Panther
# 15      2               Avengers: Infinity War
# 16      7                       Captain Marvel
#
#                                                Writer Release Date  Rating  \
# ...

# %%
marvel_summary.columns
# Out:
# Index(['index', 'MCU Movie', 'Writer', 'Release Date', 'Rating',
#        'Film Duration (mins)', 'Production Budget $', 'Box Office $',
#        '% Profit'],
#       dtype='object')

# %%
#removed index column from dataframe
marvel_summary = marvel_summary[['MCU Movie', 'Writer', 'Release Date', 'Rating',
       'Film Duration (mins)', 'Production Budget $', 'Box Office $',
       '% Profit']]
marvel_summary
# Out:
#                               MCU Movie  \
# 0                              Iron Man
# 1                            Iron Man 2
# 2                                  Thor
# 3    Captain America: The First Avenger
# 4                          The Avengers
# 5                            Iron Man 3
# 6                  Thor: The Dark World
# 7   Captain America: The Winter Soldier
# 8               Avengers: Age of Ultron
# 9                               Ant-Man
# 10           Captain America: Civil War
# 11       Guardians of the Galaxy Vol. 2
# 12               Spider-Man: Homecoming
# 13                       Thor: Ragnarok
# 14                        Black Panther
# 15               Avengers: Infinity War
# 16                       Captain Marvel
#
#                                                Writer Release Date  Rating  \
# 0                 Mark Fergus, Hawk Ostby, Art Marcum   2008-05-02    92.5
# 1                  Justin Theroux, Stan Lee, Don Heck   2010-05-07    71.5
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_axis = np.arange(len(marvel_summary))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,7))
plt.bar(x_axis, marvel_summary["Production Budget $"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, marvel_summary["MCU Movie"], rotation="vertical")
plt.xlim(0, len(x_axis))
plt.ylim(0, max(marvel_summary["Production Budget $"])+10)
plt.title("Marvel Movies Budget Figures Over 12 Years")
plt.xlabel("MCU Movie")
plt.ylabel("Box Office $")
plt.tight_layout()
plt.show()

# %%
x_axis = np.arange(len(marvel_summary))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,7))
plt.bar(x_axis, marvel_summary["Box Office $"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, marvel_summary["MCU Movie"], rotation="vertical")
plt.xlim(0, len(x_axis))
plt.ylim(0, max(marvel_summary["Box Office $"])+10)
plt.title("Marvel Movies Box Office Figures Over 12 Years")
plt.xlabel("MCU Movie")
plt.ylabel("Box Office $")
plt.tight_layout()
plt.show()

# %%
x_axis = np.arange(len(marvel_summary))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,7))
plt.bar(x_axis, marvel_summary["% Profit"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, marvel_summary["MCU Movie"], rotation="vertical")
plt.xlim(0, len(x_axis))
plt.ylim(0, max(marvel_summary["% Profit"])+10)
plt.title("Marvel Movies Box Office Figures Over 12 Years")
plt.xlabel("MCU Movie")
plt.ylabel("% Profit")
plt.tight_layout()
plt.show()

# %%
marvel_summary.plot(kind="scatter", x="MCU Movie", y="Production Budget $", color='b', figsize=(13,8),
              title="MCU Movie vs Production Budget $")
plt.xticks(rotation=90)
plt.show()

# %%
marvel_summary.plot(kind="scatter", x="MCU Movie", y="% Profit",figsize=(13,8),
              title="MCU Movie vs % Profit")
plt.xticks(rotation=90)
plt.show()

# %%
x_axis = np.arange(len(marvel_summary))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(14,8))
plt.bar(x_axis, marvel_summary["Rating"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, marvel_summary["MCU Movie"], rotation="vertical")
plt.xlim(0, len(x_axis))
plt.ylim(0, max(marvel_summary["Rating"])+10)
plt.title("Marvel Movies Average Rating")
plt.xlabel("MCU Movie")
plt.ylabel("Rating")
plt.tight_layout()
plt.show()

# %%
marvel_summary.plot(kind="scatter", x="Rating", y="Box Office $",figsize=(13,8), 
                    title="Rating vs Box Office $")

plt.show()

# %%
import hvplot.pandas
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
x_values = marvel_summary["Box Office $"]
y_values = marvel_summary["Rating"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Box Office $')
plt.ylabel('Rating')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.0473714175933161

# %%
marvel_summary.plot(kind="scatter", x="Film Duration (mins)", y="Rating",figsize=(13,8),
              title="Film Duration (mins) vs Rating")
plt.show()

# %%
x_values = marvel_summary["Film Duration (mins)"]
y_values = marvel_summary["Rating"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Film Duration (mins)')
plt.ylabel('Rating')

# Print r square value
print(f"R squared: {rvalue**2}")

# Show plot
plt.show()
# Out:
# R squared: 0.32852977362862573

# %%
marvel_summary.columns
# Out:
# Index(['MCU Movie', 'Writer', 'Release Date', 'Rating', 'Film Duration (mins)',
#        'Production Budget $', 'Box Office $', '% Profit'],
#       dtype='object')

# %%
plot_df = marvel_summary[['Writer', 'Rating', '% Profit']]
plot_df
# Out:
#                                                Writer  Rating  % Profit
# 0                 Mark Fergus, Hawk Ostby, Art Marcum    92.5     147.0
# 1                  Justin Theroux, Stan Lee, Don Heck    71.5     138.0
# 2               Ashley Miller, Zack Stentz, Don Payne    76.5     150.0
# 3      Christopher Markus, Stephen McFeely, Joe Simon    77.0     161.0
# 4                               Joss Whedon, Zak Penn    91.0     117.0
# 5                  Drew Pearce, Shane Black, Stan Lee    78.5     120.0
# 6   Christopher L. Yost, Christopher Markus, Steph...    70.5     130.0
# 7      Christopher Markus, Stephen McFeely, Joe Simon    91.0     131.0
# 8                   Joss Whedon, Stan Lee, Jack Kirby    79.5     135.0
# 9               Edgar Wright, Joe Cornish, Adam McKay    84.0     133.0
# 10     Christopher Markus, Stephen McFeely, Joe Simon    89.5     128.0
# 11               James Gunn, Dan Abnett, Andy Lanning    86.0     130.0
# ...

# %%
multi_plot = plot_df.plot(kind="bar", figsize=(10,8))

#PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(marvel_summary['Writer'], rotation="vertical")
plt.xticks(tick_locations, marvel_summary["Writer"], rotation="vertical")
plt.title("Writer Successes Over 12 Years")
plt.xlabel("Writers")

plt.tight_layout()
plt.show()

plt.show()
plt.tight_layout()
plot1_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 14
#      12 plt.show()
#      13 plt.tight_layout()
# ---> 14 plot1_df
#
# NameError: name 'plot1_df' is not defined

# %%
for i in creator:
    if i in marvel_summary["Writer/Producer"]:
    print(i)
print(i)
# Out:
#   Cell In[70], line 3
#     print(i)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
count = 0
for line in marvel_summary["Writer"]:
    if "Markus" in line:
        count = count + 1
print("Markus")
print(count)
        #print(line)
# Out:
# Markus
# 5
